# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **READING DATA FROM CSV**

# %%
df = pd.read_csv(r"C:\Users\Bliss\OneDrive\Desktop\dsbda_lab\dataset_Facebook.csv",sep = ";")

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
df.shape
# Out:
# (500, 19)

# %% [markdown]
# **CREATING SUBSETS**

# %% [markdown]
# a) Row wise

# %%
df1 = df.iloc[[1,6,15,18,25,36,45,58,67],:]
df1
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3         10
# 6             139441   Photo         3          12             1          3
# 15            138414  Status         2          12             3         10
# 18            138414  Status         3          12             2          3
# 25            138458  Status         2          12             6          3
# 36            138895   Photo         3          12             1          3
# 45            138353    Link         1          12             4          3
# 58            138329   Photo         1          11             4         10
# 67            138185   Photo         1          11             7          3
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1    0.0                      10460                            19057
# ...

# %%
df1.shape
# Out:
# (9, 19)

# %%
#Subset-2
df2 = df.iloc[[90,152,180,209,268,301,367,416,480],:]
df2

# %%
df2.shape
# Out:
# (15, 4)

# %% [markdown]
# **MERGE SUBSETS ROW-WISE**

# %%
Merg = pd.concat([df1,df2])

# %%
Merg
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3       10.0
# 6             139441   Photo         3          12             1        3.0
# 15            138414  Status         2          12             3       10.0
# 18            138414  Status         3          12             2        3.0
# 25            138458  Status         2          12             6        3.0
# 36            138895   Photo         3          12             1        3.0
# 45            138353    Link         1          12             4        3.0
# 58            138329   Photo         1          11             4       10.0
# 67            138185   Photo         1          11             7        3.0
# 16            138414     NaN         3          12             3        NaN
# 17            138414     NaN         1          12             2        NaN
# ...

# %%
Merg.shape
# Out:
# (24, 19)

# %% [markdown]
# **b) column wise**

# %%
df3 = df.iloc[:, [1,5,2,6]]
df3
# Out:
#        Type  Post Hour  Category  Paid
# 0     Photo          3         2   0.0
# 1    Status         10         2   0.0
# 2     Photo          3         3   0.0
# 3     Photo         10         2   1.0
# 4     Photo          3         2   0.0
# ..      ...        ...       ...   ...
# 495   Photo          2         3   0.0
# 496   Photo          8         2   0.0
# 497   Photo          2         1   0.0
# 498   Photo         11         3   0.0
# 499   Photo          4         2   NaN
#
# [500 rows x 4 columns]

# %%
df4 = df.iloc[:, [16,17,18]]
df4
# Out:
#        like  share  Total Interactions
# 0      79.0   17.0                 100
# 1     130.0   29.0                 164
# 2      66.0   14.0                  80
# 3    1572.0  147.0                1777
# 4     325.0   49.0                 393
# ..      ...    ...                 ...
# 495    53.0   26.0                  84
# 496    53.0   22.0                  75
# 497    93.0   18.0                 115
# 498    91.0   38.0                 136
# 499    91.0   28.0                 119
#
# [500 rows x 3 columns]

# %% [markdown]
# **MERGE SUBSETS ROW WISE**

# %%
m2 = df3.merge(df4, left_index=True, right_index=True)
m2
# Out:
#        Type  Post Hour  Category  Paid    like  share  Total Interactions
# 0     Photo          3         2   0.0    79.0   17.0                 100
# 1    Status         10         2   0.0   130.0   29.0                 164
# 2     Photo          3         3   0.0    66.0   14.0                  80
# 3     Photo         10         2   1.0  1572.0  147.0                1777
# 4     Photo          3         2   0.0   325.0   49.0                 393
# ..      ...        ...       ...   ...     ...    ...                 ...
# 495   Photo          2         3   0.0    53.0   26.0                  84
# 496   Photo          8         2   0.0    53.0   22.0                  75
# 497   Photo          2         1   0.0    93.0   18.0                 115
# 498   Photo         11         3   0.0    91.0   38.0                 136
# 499   Photo          4         2   NaN    91.0   28.0                 119
#
# [500 rows x 7 columns]

# %% [markdown]
# **SORTING VALUES**

# %%
sort_values = df.sort_values('Page total likes',ascending=False)

# %%
sort_values
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 8              139441  Status         2          12             7          3
# 1              139441  Status         2          12             3         10
# 12             139441   Photo         2          12             5         10
# 11             139441   Photo         2          12             5         10
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# **TRANSPOSE OF DATASET**

# %%
df.transpose()
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %% [markdown]
# **SHAPE DATASET**

# %%
shape = df.shape

# %%
shape
# Out:
# (500, 19)

# %%
pivot_table = pd.pivot_table(df, index=['Type','Category'],values='comment')

# %%
print(pivot_table)
# Out:
#                    comment
# Type   Category
# Link   1          2.900000
#        2          2.000000
#        3          2.000000
# Photo  1          5.897297
#        2         11.692308
#        3          6.913333
# Status 1          4.333333
#        2          9.921053
#        3          2.750000
# Video  1         12.285714

# %% [markdown]
# **RESHAPING THE DATASET**

# %%
reshape = df.melt(id_vars=["like"], value_vars=["Category", "share", "comment"])
reshape
# Out:
#         like  variable  value
# 0       79.0  Category    2.0
# 1      130.0  Category    2.0
# 2       66.0  Category    3.0
# 3     1572.0  Category    2.0
# 4      325.0  Category    2.0
# ...      ...       ...    ...
# 1495    53.0   comment    5.0
# 1496    53.0   comment    0.0
# 1497    93.0   comment    4.0
# 1498    91.0   comment    7.0
# 1499    91.0   comment    0.0
#
# [1500 rows x 3 columns]
